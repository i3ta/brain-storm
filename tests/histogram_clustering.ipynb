# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from daikon.eda.dataclasses import ImagePixelClustering

# %%
k = 2

file = f"../workflows/results/brain-tumor-50/hist/cluster/cluster_{k}.pkl"

# %%
data = ImagePixelClustering.load(file)

# %%
print(data.kmeans.inertia_)
# Out:
# 318934515475.78516
